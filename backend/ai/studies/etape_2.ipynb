# %% [markdown]
# # Étape 2
#
# ## Objectif
#
# L'étape 2 consiste à estimer un bilan économique et énergétique de la mise en oeuvre pour chacune des solution identifiées.
#
# ## Réalisation
#
# ### Données mise à dispositions
#
# Pour chaque études de cas, nous avons un ensemble de solutions mises en place afin de résoudre un problème donné. Cela signifie que l'on peut obtenir une liste de solutions, pour lesquels nous auront une liste de coûts et une liste de gains.
#
# ### Déroulement
#
# Ce qui nous intéresse ici, c'est de connaître justement ces listes de coûts et de gains en fonction du code solution en entré.
#
# ## Importation des données

# %%
import requests

response = requests.get("http://localhost:8000/rex/get_all")
dataset = response.json()
dataset
# Out:
# [{'num': 2105,
#   'reference': {'num': 1,
#    'region': {'num': 1,
#     'code_pays': 1,
#     'national_region': True,
#     'latitude': 0.0,
#     'longitude': 0.0},
#    'ville_reference': None,
#    'techno': None,
#    'code_secteur': 1,
#    'is_recup_chaleur': False},
#   'code_public': 1,
#   'monnaie': 'EUR',
#   'taux_monnaie': {'num': 1,
#    'monnaie': 'EUR',
#    'annee': 2012,
#    'valeur_taux': 1.0},
#   'gain_financier': 0,
#   'code_gain_financier_periode': 1,
#   'gain_energie': 0,
#   'code_unite_energie': 1,
#   'code_periode_energie': 1,
#   'code_energie': 0,
#   'gain_ges': 0.0,
#   'ratio_gain': 0.0,
#   'tri': 0.0,
#   'capex': 800,
#   'capex_periode': 2,
#   'opexrex': 0,
#   'techno1': {'num': 117, 'sigle': 'mar'},
#   'techno2': None,
#   'techno3': None,
#   'code_travaux': 1,
#   'code_reseau': 1,
#   'solutions': [{'num': 1611,
#     'couts': [{'num': 3294,
#       'code_solution': 1611,
#       'code_rex': 2105,
#       'cout_reel': 800000000,
# ...

# %%
dataset[0]['solutions']
# Out:
# [{'num': 1611,
#   'couts': [{'num': 3294,
#     'code_solution': 1611,
#     'code_rex': 2105,
#     'cout_reel': 800000000,
#     'monnaie': 'EUR',
#     'code_unite_cout': 1,
#     'code_difficulte': 0}],
#   'gains': []}]
